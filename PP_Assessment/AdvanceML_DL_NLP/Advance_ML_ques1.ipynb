# %%
import dask.dataframe as dd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8389afc3-a466-403a-981c-70484be2cf72" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8389afc3-a466-403a-981c-70484be2cf72">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# NOTE - from the dataset link wrong dataset is present bfs_benchmark hence just wrote the framework of model

# %%
# Load the dataset
df = dd.read_csv('facebook_friend_requests.csv')

# Clean the data
df = df.dropna()
df = df[df['friend_request_accepted'].isin([0, 1])]

# Split the data into a training set and a test set
train_df, test_df = df.random_split([0.8, 0.2])

# Choose a supervised learning algorithm
clf = LogisticRegression()

# Train the model on the training set
clf.fit(train_df[['friend_request_sent', 'friend_count']], train_df['friend_request_accepted'])

# Evaluate the model on the test set
predictions = clf.predict(test_df[['friend_request_sent', 'friend_count']])
accuracy = accuracy_score(predictions, test_df['friend_request_accepted'])

# Use the model to make predictions on new data
new_data = dd.DataFrame({'friend_request_sent': [1], 'friend_count': [10]})
predictions = clf.predict(new_data)

# %% [markdown]
# You can use MLflow to track the performance of your model and to reproduce the results of your experiments. To do this, you will need to install MLflow and create a tracking server. Once you have done this, you can use the mlflow.log_metric() and mlflow.log_artifact() functions to track the performance of your model and to store the model itself.
#
# Here is an example of how to use MLflow to track the performance of your model:

# %%
import mlflow

# Log the accuracy of the model
mlflow.log_metric('accuracy', accuracy)

# Log the model itself
mlflow.log_artifact('model', clf)
